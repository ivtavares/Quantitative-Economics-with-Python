# %% [markdown]
# # About Python

# %% [markdown]
# ## Scientific Programming

# %% [markdown]
# ### Numerical Programming

# %%
import numpy as np #Load library
a = np.linspace(-np.pi, np.pi, 100) #create even grid from pi to -pi
b = np.cos(a)
c = np.sin(a)

# %%
b @ c
# Out:
# 9.853229343548264e-16

# %%
from scipy.stats import norm
from scipy.integrate import quad
fi = norm()
value, error = quad(fi.pdf, -2, 2) #Integrate using Gaussian quadrature
value
# Out:
# 0.9544997361036417

# %% [markdown]
# ### Symbolic Algebra

# %%
from sympy import Symbol
x, y = Symbol('x'), Symbol('y') # Treat 'x' and 'y' as algebra symbols
x + x + x + y
# Out:
# 3*x + y

# %%
expression = (x + y)**2
expression.expand()
# Out:
# x**2 + 2*x*y + y**2

# %%
from sympy import solve
solve(x**2 + x + 2)
# Out:
# [-1/2 - sqrt(7)*I/2, -1/2 + sqrt(7)*I/2]

# %%
from sympy import limit, sin, diff
limit(1/ x, x, 0)
# Out:
# oo

# %%
limit(sin(x) / x, x, 0)
# Out:
# 1

# %%
diff(sin(x), x)
# Out:
# cos(x)

# %% [markdown]
# ### Statistics

# %% [markdown]
# #### Pandas

# %%
import pandas as pd
np.random.seed(1234)
data = np.random.randn(5, 2) #5x2 matrix of N(0, 1) random draws
dates = pd.date_range('28/12/2010', periods=5)
df = pd.DataFrame(data, columns=('price',  'weight'), index=dates)
print(df)
# Out:
#                price    weight
# 2010-12-28  0.471435 -1.190976
# 2010-12-29  1.432707 -0.312652
# 2010-12-30 -0.720589  0.887163
# 2010-12-31  0.859588 -0.636524
# 2011-01-01  0.015696 -2.242685

# %%
df.mean()
# Out:
# price     0.411768
# weight   -0.699135
# dtype: float64

# %% [markdown]
# ### Networks and Graphs

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(1234)

# Generate a random graph
p = dict((i, (np.random.uniform(0, 1), np.random.uniform(0, 1)))
         for i in range(200))
g = nx.random_geometric_graph(200, 0.12, pos=p)
pos = nx.get_node_attributes(g, 'pos')

# Find node nearest the center point (0.5, 0.5)
dists = [(x - 0.5)**2 + (y - 0.5)**2 for x, y in list(pos.values())]
ncenter = np.argmin(dists)

# Plot graph, coloring by path length from central node
p = nx.single_source_shortest_path_length(g, ncenter)
plt.figure()
nx.draw_networkx_edges(g, pos, alpha=0.4)
nx.draw_networkx_nodes(g,
                      pos,
                      nodelist=list(p.keys()),
                      node_size=120, aplha=0.5,
                      node_color=list(p.values()),
                      cmap=plt.cm.jet_r)
# Out:
# /home/igor/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
# Out:
#   File "<ipython-input-35-53715a8e3bef>", line 1
#     \alpha
#           ^
# SyntaxError: unexpected character after line continuation character
